# %% [markdown]
# # EduPro model development
#
# Benchmark all required regressors and inspect the selected model for each target.

# %%
import sys
sys.path.append('..')
from data_pipeline import load_cleaned_data
from modeling import train_all_models
data = load_cleaned_data('../data/edupro_merged_cleaned.csv')
model_results = train_all_models(data)

# %%
for target_name, target_result in model_results.items():
    print(target_name)
    display(target_result['table'])
    print('Selected:', target_result['best_name'])
