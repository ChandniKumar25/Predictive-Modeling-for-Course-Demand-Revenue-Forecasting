# %% [markdown]
# # EduPro preprocessing and feature engineering
#
# This notebook documents the engineered features used by the app.

# %%
import pandas as pd
data = pd.read_csv('../data/edupro_merged_cleaned.csv')
feature_columns = ['PriceBand','DurationBucket','RatingTier','ExperienceBucket','ExpertiseCategoryMatch','HistoricalEnrollmentCount','PastAverageRevenue','RevenuePerEnrollment']
data[feature_columns].head()

# %%
data[feature_columns].isna().sum()
